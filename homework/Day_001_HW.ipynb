# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# %%
def mean_squared_error(y, yp):
    """
    請完成這個 Function 後往下執行
    """
    mse = ((y - yp)**2).mean()
    return mse

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 227.340
# The Mean absolute error is 11.892

# %% [markdown]
# # 作業1

# %% [markdown]
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
# https://www.kaggle.com/jsphyg/weather-dataset-rattle-package
#
# 1. 你選的這組資料為何重要
#  > 預測明天Australian是否會下雨。好奇是否可用歷史數據順練出比衛星雲圖準的模型。
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#  > 由眾多澳大利亞氣象站的每日天氣觀數據。
# 3. 蒐集而來的資料型態為何
#  > 結構化：24columns，包含數值/日期/類別
#  4. 這組資料想解決的問題如何評估
#  > Recall 未雨綢繆總是好的。或是權衡Recall 和 Precision的 F1score。

# %% [markdown]
# # 作業2

# %% [markdown]
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#  >  先調查自己的車隊，當客戶數量提升時是否有能力處理，是否車隊接案數已達飽和，如果已達飽和則可增加司機。或是車隊安排的任務尚有優化的空間。
#          如車隊接案數未達飽和，則可研究是否有競爭對手：
#                  如果有，可設計問卷調查客戶選擇車隊時的考量，並研究改善的可行性。
#                  如果無，調查車隊宣傳狀況，分析重點目標客戶族群及相對應的消費能力，選擇最有利益的族群，進行廣告投擲。
#           亦須調查該產業使否已飽和？或是該產業正在萎縮，是否是擴展的時機。
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#  > 車隊每位司機的接案數據，包含時間，接送地點，載客人數，客戶來源等資訊，可進行任務排程的優化。
#     市場滿意度調查，選擇本車隊的理由，快速？價格實惠？安全？環境乾淨？等資訊。
#     車隊宣傳狀況，市場調查，是否聽過本車隊？從哪個管道？如果未來有需要是否願意搭乘？可能搭乘的接送地點？等資訊。
# 3. 蒐集而來的資料型態為何
#  >  皆為結構化數據，應會涵蓋時間/數值/類別。
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#  > 車隊每位司機的接案數據，計算司機平均等待時間，可使用基因演算法，參考OEE評估工單排程優劣。
#     市場滿意度調查: A/B測試，比較本車隊與其他車隊差異。預測改善某些項目，期望滿意度為多少，可用ＭＡＥ。
#     車隊宣傳狀況: 預測廣告投擲效益，可用ＭＡＥ。
